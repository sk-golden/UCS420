# %% [markdown]
# Q.1 For the array gfg = np.matrix('[4, 1, 9; 12, 3, 1; 4, 5, 6]'), Find
# i. Sum of all elements
# ii. Sum of all elements row-wise
# iii. Sum of all elements column-wise

# %%
import numpy as np

gfg = np.matrix('[4, 1, 9; 12, 3, 1; 4, 5, 6]')

# (i)
total_sum = np.sum(gfg)

# (ii)
row_wise_sum = np.sum(gfg, axis=1)

# (iii)
col_wise_sum = np.sum(gfg, axis=0)

print("Q1:")
print("Total Sum:", total_sum)
print("Row-wise Sum:\n", row_wise_sum)
print("Column-wise Sum:\n", col_wise_sum)
# Out:
# Q1:
# Total Sum: 45
# Row-wise Sum:
#  [[14]
#  [16]
#  [15]]
# Column-wise Sum:
#  [[20  9 16]]

# %% [markdown]
# Q.2 (a)For the array: array = np.array([10, 52, 62, 16, 16, 54, 453]), find
# i. Sorted array
# ii. Indices of sorted array
# iii. 4 smallest elements
# iv. 5 largest elements

# %%
array = np.array([10, 52, 62, 16, 16, 54, 453])

# (i)
sorted_array = np.sort(array)

# (ii)
sorted_indices = np.argsort(array)

# (iii)
smallest_elements = np.sort(array)[:4]

# (iv)
largest_elements = np.sort(array)[-5:]

print("\nQ2:")
print("Sorted Array:", sorted_array)
print("Indices of Sorted Array:", sorted_indices)
print("4 Smallest Elements:", smallest_elements)
print("5 Largest Elements:", largest_elements)
# Out:
# Q2:
# Sorted Array: [ 10  16  16  52  54  62 453]
# Indices of Sorted Array: [0 3 4 1 5 2 6]
# 4 Smallest Elements: [10 16 16 52]
# 5 Largest Elements: [ 16  52  54  62 453]

# %% [markdown]
# (b) For the array: array = np.array([1.0, 1.2, 2.2, 2.0, 3.0, 2.0]), find
# i. Integer elements only
# ii. Float elements only

# %%
array_b = np.array([1.0, 1.2, 2.2, 2.0, 3.0, 2.0])

# (i)
integer_elements = array_b[array_b == array_b.astype(int)]

# (ii)
float_elements = array_b[array_b != array_b.astype(int)]

print("\nQ2 (b):")
print("Integer Elements:", integer_elements)
print("Float Elements:", float_elements)
# Out:
# Q2 (b):
# Integer Elements: [1. 2. 3. 2.]
# Float Elements: [1.2 2.2]

# %% [markdown]
# Q.3 You are given a weekly sales dataset and need to perform various operations
# using NumPy broadcasting.
# a) Generate your unique sales dataset:
#  Take the sum of the ASCII values of the initials of your first and last
# name. Call this value X. (If your initials are A B → ASCII sum = 65
# + 66 = 131 → sales = [131, 181, 231, 281, 331].)
#  Create a NumPy array sales with values [X, X+50, X+100, X+150,
# X+200].
# b) Compute your personalized tax rate as ((X % 5) + 5) / 100.
#  Use broadcasting to apply this tax rate to each sales value.
# c) Adjust sales based on discount:
#  If sales < X+100, apply a 5% discount.
#  If sales >= X+100, apply a 10% discount.
# d) Expand sales data for multiple weeks:
#  Create a 3×5 matrix representing three weeks of sales by stacking
# sales three times using broadcasting.
#  Increase sales by 2% per week using element-wise broadcasting.

# %%
X = 131
sales = np.array([X, X+50, X+100, X+150, X+200])

# (b)
tax_rate = ((X % 5) + 5) / 100
sales_with_tax = sales * (1 + tax_rate)

# (c)
discounted_sales = np.where(sales < X+100, sales * 0.95, sales * 0.90)

# (d)
sales_weeks = np.tile(sales, (3, 1))
weekly_multiplier = np.array([1.00, 1.02, 1.04]).reshape(3, 1)
adjusted_sales_weeks = sales_weeks * weekly_multiplier

print("\nQ3:")
print("Sales Array:", sales)
print("Tax Rate Applied:", sales_with_tax)
print("Discounted Sales:", discounted_sales)
print("Sales Data for Multiple Weeks:\n", adjusted_sales_weeks)
# Out:
# Q3:
# Sales Array: [131 181 231 281 331]
# Tax Rate Applied: [138.86 191.86 244.86 297.86 350.86]
# Discounted Sales: [124.45 171.95 207.9  252.9  297.9 ]
# Sales Data for Multiple Weeks:
#  [[131.   181.   231.   281.   331.  ]
#  [133.62 184.62 235.62 286.62 337.62]
#  [136.24 188.24 240.24 292.24 344.24]]

# %% [markdown]
# Q4. Generate x values using np.linspace() from -10 to 10 with 100 points. Use
# each function from the list below and compute y values using NumPy:
#  Y = x2
#  Y = sin(x)
#  Y = ex
#  Y = log(|x| + 1)
# Plot the chosen function using Matplotlib. Add title, labels, and grid for clarity.

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(-10, 10, 100)


y1 = x**2
y2 = np.sin(x)
y3 = np.exp(x)
y4 = np.log(np.abs(x) + 1)


fig, axes = plt.subplots(2, 2, figsize=(10, 8))

axes[0, 0].plot(x, y1, label=r'$y = x^2$', color='b')
axes[0, 0].set_title('Quadratic Function')
axes[0, 0].set_xlabel('x')
axes[0, 0].set_ylabel('y')
axes[0, 0].grid(True)
axes[0, 0].legend()

axes[0, 1].plot(x, y2, label=r'$y = \sin(x)$', color='g')
axes[0, 1].set_title('Sine Function')
axes[0, 1].set_xlabel('x')
axes[0, 1].set_ylabel('y')
axes[0, 1].grid(True)
axes[0, 1].legend()

axes[1, 0].plot(x, y3, label=r'$y = e^x$', color='r')
axes[1, 0].set_title('Exponential Function')
axes[1, 0].set_xlabel('x')
axes[1, 0].set_ylabel('y')
axes[1, 0].grid(True)
axes[1, 0].legend()

axes[1, 1].plot(x, y4, label=r'$y = \log(|x| + 1)$', color='m')
axes[1, 1].set_title('Logarithmic Function')
axes[1, 1].set_xlabel('x')
axes[1, 1].set_ylabel('y')
axes[1, 1].grid(True)
axes[1, 1].legend()

plt.tight_layout()
plt.show()
